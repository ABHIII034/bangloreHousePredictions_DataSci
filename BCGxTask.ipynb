# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("financials.csv")

# %%
df.head()
# Out:
#      Company  Year  TotalRevenue  NetIncome  TotalAssets  TotalLiabilities  \
# 0  Microsoft  2022         198.3       72.7          NaN               NaN
# 1  Microsoft  2023         211.9       72.4          NaN               NaN
# 2  Microsoft  2024         245.1       88.0          NaN               NaN
# 3      Tesla  2022          81.5       12.6          NaN               NaN
# 4      Tesla  2023          96.8       14.9          NaN               NaN
#
#    CashFlowFromOps
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           9 non-null      object
#  1   Year              9 non-null      int64
#  2   TotalRevenue      9 non-null      float64
#  3   NetIncome         9 non-null      float64
#  4   TotalAssets       0 non-null      float64
#  5   TotalLiabilities  0 non-null      float64
#  6   CashFlowFromOps   0 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 636.0+ bytes

# %%
df.describe()
# Out:
#               Year  TotalRevenue   NetIncome  TotalAssets  TotalLiabilities  \
# count     9.000000      9.000000    9.000000          0.0               0.0
# mean   2023.000000    232.733333   62.811111          NaN               NaN
# std       0.866025    129.194098   39.911698          NaN               NaN
# min    2022.000000     81.500000    7.000000          NaN               NaN
# 25%    2022.000000     97.700000   14.900000          NaN               NaN
# 50%    2023.000000    211.900000   72.700000          NaN               NaN
# 75%    2024.000000    383.300000   97.000000          NaN               NaN
# max    2024.000000    394.300000  100.900000          NaN               NaN
#
#        CashFlowFromOps
# count              0.0
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
df.sort_values(["Company","Year"])
# Out:
#      Company  Year  TotalRevenue  NetIncome  TotalAssets  TotalLiabilities  \
# 6      Apple  2022         394.3       99.8          NaN               NaN
# 7      Apple  2023         383.3       97.0          NaN               NaN
# 8      Apple  2024         385.7      100.9          NaN               NaN
# 0  Microsoft  2022         198.3       72.7          NaN               NaN
# 1  Microsoft  2023         211.9       72.4          NaN               NaN
# 2  Microsoft  2024         245.1       88.0          NaN               NaN
# 3      Tesla  2022          81.5       12.6          NaN               NaN
# 4      Tesla  2023          96.8       14.9          NaN               NaN
# 5      Tesla  2024          97.7        7.0          NaN               NaN
#
#    CashFlowFromOps
# 6              NaN
# 7              NaN
# 8              NaN
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN

# %%
df["'Revenue Growth (%)"]=df.groupby("Company")["TotalRevenue"].pct_change()*100

# %%
df
# Out:
#      Company  Year  TotalRevenue  NetIncome  TotalAssets  TotalLiabilities  \
# 0  Microsoft  2022         198.3       72.7          NaN               NaN
# 1  Microsoft  2023         211.9       72.4          NaN               NaN
# 2  Microsoft  2024         245.1       88.0          NaN               NaN
# 3      Tesla  2022          81.5       12.6          NaN               NaN
# 4      Tesla  2023          96.8       14.9          NaN               NaN
# 5      Tesla  2024          97.7        7.0          NaN               NaN
# 6      Apple  2022         394.3       99.8          NaN               NaN
# 7      Apple  2023         383.3       97.0          NaN               NaN
# 8      Apple  2024         385.7      100.9          NaN               NaN
#
#    CashFlowFromOps  'Revenue Growth (%)
# 0              NaN                  NaN
# 1              NaN             6.858296
# 2              NaN            15.667768
# 3              NaN                  NaN
# ...

# %%
df['Net Income Growth (%)'] = df.groupby('Company')['NetIncome'].pct_change() * 100

# %%
df
# Out:
#      Company  Year  TotalRevenue  NetIncome  TotalAssets  TotalLiabilities  \
# 0  Microsoft  2022         198.3       72.7          NaN               NaN
# 1  Microsoft  2023         211.9       72.4          NaN               NaN
# 2  Microsoft  2024         245.1       88.0          NaN               NaN
# 3      Tesla  2022          81.5       12.6          NaN               NaN
# 4      Tesla  2023          96.8       14.9          NaN               NaN
# 5      Tesla  2024          97.7        7.0          NaN               NaN
# 6      Apple  2022         394.3       99.8          NaN               NaN
# 7      Apple  2023         383.3       97.0          NaN               NaN
# 8      Apple  2024         385.7      100.9          NaN               NaN
#
#    CashFlowFromOps  'Revenue Growth (%)  Net Income Growth (%)
# 0              NaN                  NaN                    NaN
# 1              NaN             6.858296              -0.412655
# ...

# %%
df['Assets Growth (%)'] = df.groupby('Company')['TotalAssets'].pct_change() * 100
# Out:
# C:\Users\Mihir Sonawane\AppData\Local\Temp\ipykernel_20924\2768074588.py:1: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Assets Growth (%)'] = df.groupby('Company')['TotalAssets'].pct_change() * 100

# %%
df['Liabilities Growth (%)'] = df.groupby('Company')['TotalLiabilities'].pct_change() * 100
# Out:
# C:\Users\Mihir Sonawane\AppData\Local\Temp\ipykernel_20924\1658663041.py:1: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['Liabilities Growth (%)'] = df.groupby('Company')['TotalLiabilities'].pct_change() * 100

# %%
df['CashFlow Growth (%)'] = df.groupby('Company')['CashFlowFromOps'].pct_change() * 100
# Out:
# C:\Users\Mihir Sonawane\AppData\Local\Temp\ipykernel_20924\2411692175.py:1: FutureWarning: The default fill_method='ffill' in SeriesGroupBy.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   df['CashFlow Growth (%)'] = df.groupby('Company')['CashFlowFromOps'].pct_change() * 100

# %%
df
# Out:
#      Company  Year  TotalRevenue  NetIncome  TotalAssets  TotalLiabilities  \
# 0  Microsoft  2022         198.3       72.7          NaN               NaN
# 1  Microsoft  2023         211.9       72.4          NaN               NaN
# 2  Microsoft  2024         245.1       88.0          NaN               NaN
# 3      Tesla  2022          81.5       12.6          NaN               NaN
# 4      Tesla  2023          96.8       14.9          NaN               NaN
# 5      Tesla  2024          97.7        7.0          NaN               NaN
# 6      Apple  2022         394.3       99.8          NaN               NaN
# 7      Apple  2023         383.3       97.0          NaN               NaN
# 8      Apple  2024         385.7      100.9          NaN               NaN
#
#    CashFlowFromOps  'Revenue Growth (%)  Net Income Growth (%)  \
# 0              NaN                  NaN                    NaN
# 1              NaN             6.858296              -0.412655
# ...
